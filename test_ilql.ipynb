# %%
from omegaconf import OmegaConf

class MakeObj(object):
    """ dictionary to object.
    Thanks to https://stackoverflow.com/questions/1305532/convert-nested-python-dict-to-object

    Args:
        object ([type]): [description]
    """
    def __init__(self, d):
        for a, b in d.items():
            if isinstance(b, (list, tuple)):
                setattr(self, a, [MakeObj(x) if isinstance(x, dict) else x for x in b])
            else:
                setattr(self, a, MakeObj(b) if isinstance(b, dict) else b)


def read_yaml(path):
    x_dict =  OmegaConf.load(path)
    x_yamlstr = OmegaConf.to_yaml(x_dict)
    x_obj = MakeObj(x_dict)
    return x_yamlstr, x_dict, x_obj

x_yamlstr, x_dict, config = read_yaml('configs/end_to_end/train/ilql/run.yaml')

# %%
from hydra.utils import instantiate
model = instantiate(config.experiment)
# Out:
# [2024-02-14 17:34:56,624] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2024-02-14 17:34:59.895 | INFO     | models.end_to_end.tactic_models.gen_tac_model:__init__:46 - Without retrieval
# 2024-02-14 17:34:59.935 | INFO     | models.end_to_end.tactic_models.gen_tac_model:__init__:65 - LoRA:
# T5ForConditionalGeneration(
#   (shared): Embedding(384, 1472)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-3): 3 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1472, out_features=384, bias=False)
#               (k): Linear(in_features=1472, out_features=384, bias=False)
#               (v): Linear(in_features=1472, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=1472, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(in_features=3584, out_features=1472, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1472, out_features=384, bias=False)
# )
# trainable params: 3,699,712 || all params: 303,337,472 || trainable%: 1.2196686336200495
# T5ForConditionalGeneration(
#   (shared): Embedding(384, 1472)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(
#                 in_features=3584, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(
#                 in_features=3584, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(384, 1472)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(
#                 in_features=3584, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-3): 3 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v): Linear(
#                 in_features=1472, out_features=384, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1472, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=384, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o): Linear(
#                 in_features=384, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=384, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1472, out_features=3584, bias=False)
#               (wi_1): Linear(in_features=1472, out_features=3584, bias=False)
#               (wo): Linear(
#                 in_features=3584, out_features=1472, bias=False
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.01, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3584, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1472, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(
#     in_features=1472, out_features=384, bias=False
#     (lora_dropout): ModuleDict(
#       (default): Dropout(p=0.01, inplace=False)
#     )
#     (lora_A): ModuleDict(
#       (default): Linear(in_features=1472, out_features=16, bias=False)
#     )
#     (lora_B): ModuleDict(
#       (default): Linear(in_features=16, out_features=384, bias=False)
#     )
#     (lora_embedding_A): ParameterDict()
#     (lora_embedding_B): ParameterDict()
#   )
# )

# %%
# model.batch_generate(['x : ℝ\n⊢ log |x| = log x', 'n : ℕ∞,\nh : n ≤ 0\n⊢ ↑0 - ↑n ≤ ↑(0 - n)'], None, 2)
model.batch_generate(['abc', 'abcde'], None, 3)
# Out:
# (tensor([[[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527]]]],
#        grad_fn=<CatBackward0>), tensor([[[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205]]]],
#        grad_fn=<CatBackward0>), tensor([[[[-0.3222, -0.0932, -0.3891,  ..., -0.0825,  0.1823, -0.5681]],
#
#          [[ 0.0293, -0.1256,  0.0506,  ..., -0.1351, -0.1188,  0.0703]],
#
#          [[ 0.2754,  0.0503,  0.5437,  ..., -0.3932,  0.5606, -0.4843]],
#
#          [[-0.1321,  0.1148, -0.0330,  ..., -0.0347, -0.2644,  0.1078]],
#
#          [[-0.2378,  0.0605,  0.1844,  ..., -0.0683, -0.0740,  0.4760]],
#
#          [[-0.1832, -0.3329,  0.3704,  ...,  0.3169, -0.4514, -0.0897]]],
#
#
#         [[[-0.3222, -0.0932, -0.3891,  ..., -0.0825,  0.1823, -0.5681]],
#
#          [[ 0.0293, -0.1256,  0.0506,  ..., -0.1351, -0.1188,  0.0703]],
#
#          [[ 0.2754,  0.0503,  0.5437,  ..., -0.3932,  0.5606, -0.4843]],
#
#          [[-0.1321,  0.1148, -0.0330,  ..., -0.0347, -0.2644,  0.1078]],
#
#          [[-0.2378,  0.0605,  0.1844,  ..., -0.0683, -0.0740,  0.4760]],
#
#          [[-0.1832, -0.3329,  0.3704,  ...,  0.3169, -0.4514, -0.0897]]],
#
#
#         [[[-0.3222, -0.0932, -0.3891,  ..., -0.0825,  0.1823, -0.5681]],
#
#          [[ 0.0293, -0.1256,  0.0506,  ..., -0.1351, -0.1188,  0.0703]],
#
#          [[ 0.2754,  0.0503,  0.5437,  ..., -0.3932,  0.5606, -0.4843]],
#
#          [[-0.1321,  0.1148, -0.0330,  ..., -0.0347, -0.2644,  0.1078]],
#
#          [[-0.2378,  0.0605,  0.1844,  ..., -0.0683, -0.0740,  0.4760]],
#
#          [[-0.1832, -0.3329,  0.3704,  ...,  0.3169, -0.4514, -0.0897]]],
#
#
#         [[[ 0.6561,  0.4484, -0.8270,  ..., -0.0631, -0.4154, -0.0385]],
#
#          [[-0.1486,  0.5289, -0.0567,  ...,  0.9928,  2.4893, -0.1424]],
#
#          [[ 0.4679,  0.2323,  0.3591,  ...,  0.2027, -2.6141, -0.0912]],
#
#          [[-0.0516,  0.1707, -0.4086,  ..., -0.4846,  1.2426,  0.3884]],
#
#          [[ 0.0751,  1.0551, -0.3409,  ..., -0.2638,  0.1710, -0.3605]],
#
#          [[-0.6652,  0.2447,  0.3697,  ..., -1.5821,  1.2442,  0.2803]]],
#
#
#         [[[ 0.6561,  0.4484, -0.8270,  ..., -0.0631, -0.4154, -0.0385]],
#
#          [[-0.1486,  0.5289, -0.0567,  ...,  0.9928,  2.4893, -0.1424]],
#
#          [[ 0.4679,  0.2323,  0.3591,  ...,  0.2027, -2.6141, -0.0912]],
#
#          [[-0.0516,  0.1707, -0.4086,  ..., -0.4846,  1.2426,  0.3884]],
#
#          [[ 0.0751,  1.0551, -0.3409,  ..., -0.2638,  0.1710, -0.3605]],
#
#          [[-0.6652,  0.2447,  0.3697,  ..., -1.5821,  1.2442,  0.2803]]],
#
#
#         [[[ 0.6561,  0.4484, -0.8270,  ..., -0.0631, -0.4154, -0.0385]],
#
#          [[-0.1486,  0.5289, -0.0567,  ...,  0.9928,  2.4893, -0.1424]],
#
#          [[ 0.4679,  0.2323,  0.3591,  ...,  0.2027, -2.6141, -0.0912]],
#
#          [[-0.0516,  0.1707, -0.4086,  ..., -0.4846,  1.2426,  0.3884]],
#
#          [[ 0.0751,  1.0551, -0.3409,  ..., -0.2638,  0.1710, -0.3605]],
#
#          [[-0.6652,  0.2447,  0.3697,  ..., -1.5821,  1.2442,  0.2803]]]],
#        grad_fn=<TransposeBackward0>), tensor([[[[ 0.0493, -0.1618, -0.3420,  ..., -0.0885, -0.1365, -0.0890]],
#
#          [[ 0.1602, -0.1627, -0.1240,  ..., -0.1444,  0.2562,  0.0624]],
#
#          [[-0.1742, -0.0484,  0.1766,  ..., -0.1187,  0.1363,  0.1846]],
#
#          [[-0.1020,  0.0571,  0.0037,  ..., -0.1793,  0.1849,  0.0349]],
#
#          [[-0.3020,  0.3706, -0.2776,  ...,  0.0958,  0.4664,  0.1455]],
#
#          [[ 0.1769,  0.1793, -0.0019,  ...,  0.0305, -0.2088, -0.2223]]],
#
#
#         [[[ 0.0493, -0.1618, -0.3420,  ..., -0.0885, -0.1365, -0.0890]],
#
#          [[ 0.1602, -0.1627, -0.1240,  ..., -0.1444,  0.2562,  0.0624]],
#
#          [[-0.1742, -0.0484,  0.1766,  ..., -0.1187,  0.1363,  0.1846]],
#
#          [[-0.1020,  0.0571,  0.0037,  ..., -0.1793,  0.1849,  0.0349]],
#
#          [[-0.3020,  0.3706, -0.2776,  ...,  0.0958,  0.4664,  0.1455]],
#
#          [[ 0.1769,  0.1793, -0.0019,  ...,  0.0305, -0.2088, -0.2223]]],
#
#
#         [[[ 0.0493, -0.1618, -0.3420,  ..., -0.0885, -0.1365, -0.0890]],
#
#          [[ 0.1602, -0.1627, -0.1240,  ..., -0.1444,  0.2562,  0.0624]],
#
#          [[-0.1742, -0.0484,  0.1766,  ..., -0.1187,  0.1363,  0.1846]],
#
#          [[-0.1020,  0.0571,  0.0037,  ..., -0.1793,  0.1849,  0.0349]],
#
#          [[-0.3020,  0.3706, -0.2776,  ...,  0.0958,  0.4664,  0.1455]],
#
#          [[ 0.1769,  0.1793, -0.0019,  ...,  0.0305, -0.2088, -0.2223]]],
#
#
#         [[[ 0.1239,  0.2390, -0.4618,  ...,  0.2895,  0.2374, -0.8741]],
#
#          [[-0.3576, -0.1950, -0.0545,  ..., -0.1913, -0.5255,  0.4455]],
#
#          [[-0.7488,  0.4497,  0.2046,  ...,  0.3346,  1.0018, -0.6196]],
#
#          [[ 0.2011,  0.3689, -1.2674,  ..., -0.1007,  0.1328,  0.0447]],
#
#          [[-0.2857, -0.7774,  0.2206,  ...,  0.7364, -0.7619, -0.2138]],
#
#          [[-0.4032,  0.6052,  0.1964,  ...,  0.8591,  1.0738,  0.0198]]],
#
#
#         [[[ 0.1239,  0.2390, -0.4618,  ...,  0.2895,  0.2374, -0.8741]],
#
#          [[-0.3576, -0.1950, -0.0545,  ..., -0.1913, -0.5255,  0.4455]],
#
#          [[-0.7488,  0.4497,  0.2046,  ...,  0.3346,  1.0018, -0.6196]],
#
#          [[ 0.2011,  0.3689, -1.2674,  ..., -0.1007,  0.1328,  0.0447]],
#
#          [[-0.2857, -0.7774,  0.2206,  ...,  0.7364, -0.7619, -0.2138]],
#
#          [[-0.4032,  0.6052,  0.1964,  ...,  0.8591,  1.0738,  0.0198]]],
#
#
#         [[[ 0.1239,  0.2390, -0.4618,  ...,  0.2895,  0.2374, -0.8741]],
#
#          [[-0.3576, -0.1950, -0.0545,  ..., -0.1913, -0.5255,  0.4455]],
#
#          [[-0.7488,  0.4497,  0.2046,  ...,  0.3346,  1.0018, -0.6196]],
#
#          [[ 0.2011,  0.3689, -1.2674,  ..., -0.1007,  0.1328,  0.0447]],
#
#          [[-0.2857, -0.7774,  0.2206,  ...,  0.7364, -0.7619, -0.2138]],
#
#          [[-0.4032,  0.6052,  0.1964,  ...,  0.8591,  1.0738,  0.0198]]]],
#        grad_fn=<TransposeBackward0>))
# (tensor([[[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.1244, -0.0047,  0.0753,  ...,  0.8420,  0.0343,  0.0193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1095,  0.1602, -0.0134,  ...,  0.1771,  0.0561,  0.1152],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1649, -0.5671, -0.5504,  ...,  0.0447, -0.1243, -1.1302],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3057,  0.0545,  0.0365,  ..., -0.0737, -0.0128, -0.3064],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.2112, -0.0183,  0.1289,  ..., -0.0264, -0.0354, -0.0905],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0363,  0.1197,  0.7622,  ..., -0.0245, -0.1234, -0.1527],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]],
#        grad_fn=<CatBackward0>), tensor([[[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.6858, -0.1056,  0.1451,  ...,  0.3123,  0.0918, -0.0811],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0195, -0.4439,  0.0826,  ...,  0.6275, -0.5131,  0.0827],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.1172,  0.1728,  0.1919,  ..., -0.3419, -0.1360,  0.2530],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.1304, -0.0914, -0.2510,  ...,  0.1694, -0.1734,  0.0079],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2420, -0.2331, -0.0904,  ...,  0.1827, -0.4986, -0.2915],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0401,  0.2288,  0.1391,  ...,  0.1564, -0.0165, -0.4205],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
# ...
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[ 0.1144, -0.0719, -0.3227,  ..., -0.2601, -0.5751, -0.0996],
#           [-0.4951,  0.0029, -0.4028,  ..., -0.1097, -0.2241, -0.1469],
#           [-0.0346, -0.5480, -0.3631,  ..., -0.3113, -0.3875,  0.3237],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2289, -0.3084, -0.1469,  ..., -0.2071, -0.1442,  0.0383],
#           [ 0.0891, -0.5219, -0.1188,  ..., -0.5359,  0.0925,  0.2267],
#           [ 0.1576,  0.5716,  0.2655,  ..., -0.1267,  0.3403,  0.0694],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.4351,  0.8521,  0.4506,  ..., -0.7985, -0.0609, -0.2762],
#           [-0.1364,  0.7779,  0.1741,  ..., -0.4257,  0.4328, -0.1961],
#           [ 0.2043,  0.5910,  0.0121,  ..., -0.0555,  0.4647, -0.1795],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2064,  1.0273,  0.0979,  ..., -0.3015, -0.6399, -0.3302],
#           [ 0.1217,  0.5922, -0.1093,  ..., -0.3748, -0.2035, -0.4244],
#           [ 0.1837,  0.3573,  0.1316,  ..., -0.3439, -0.0781, -0.4942],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0736, -0.0054, -0.3919,  ..., -0.0721, -0.0641,  0.9010],
#           [ 0.4972,  0.0403, -0.3325,  ...,  0.4875,  0.2821,  0.3690],
#           [ 0.2656, -0.3423, -0.4252,  ..., -0.1172,  0.1597,  0.9568],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0089,  0.2645,  0.6018,  ...,  0.4933,  0.0629, -0.4297],
#           [-0.2172,  0.1532,  0.6371,  ...,  0.5179, -0.0223, -0.2761],
#           [-0.0150,  0.2502,  0.3327,  ...,  0.1801,  0.3622, -0.1909],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[ 0.1144, -0.0719, -0.3227,  ..., -0.2601, -0.5751, -0.0996],
#           [-0.4951,  0.0029, -0.4028,  ..., -0.1097, -0.2241, -0.1469],
#           [-0.0346, -0.5480, -0.3631,  ..., -0.3113, -0.3875,  0.3237],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2289, -0.3084, -0.1469,  ..., -0.2071, -0.1442,  0.0383],
#           [ 0.0891, -0.5219, -0.1188,  ..., -0.5359,  0.0925,  0.2267],
#           [ 0.1576,  0.5716,  0.2655,  ..., -0.1267,  0.3403,  0.0694],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.4351,  0.8521,  0.4506,  ..., -0.7985, -0.0609, -0.2762],
#           [-0.1364,  0.7779,  0.1741,  ..., -0.4257,  0.4328, -0.1961],
#           [ 0.2043,  0.5910,  0.0121,  ..., -0.0555,  0.4647, -0.1795],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2064,  1.0273,  0.0979,  ..., -0.3015, -0.6399, -0.3302],
#           [ 0.1217,  0.5922, -0.1093,  ..., -0.3748, -0.2035, -0.4244],
#           [ 0.1837,  0.3573,  0.1316,  ..., -0.3439, -0.0781, -0.4942],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0736, -0.0054, -0.3919,  ..., -0.0721, -0.0641,  0.9010],
#           [ 0.4972,  0.0403, -0.3325,  ...,  0.4875,  0.2821,  0.3690],
#           [ 0.2656, -0.3423, -0.4252,  ..., -0.1172,  0.1597,  0.9568],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0089,  0.2645,  0.6018,  ...,  0.4933,  0.0629, -0.4297],
#           [-0.2172,  0.1532,  0.6371,  ...,  0.5179, -0.0223, -0.2761],
#           [-0.0150,  0.2502,  0.3327,  ...,  0.1801,  0.3622, -0.1909],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.0111,  0.0752, -0.1729,  ..., -0.3037, -0.5318, -0.1212],
#           [-0.7403,  0.2752, -0.1268,  ..., -0.0615, -0.1890, -0.4265],
#           [-0.2375,  0.0325, -0.0336,  ..., -0.3959, -0.1566, -0.3972],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2788, -0.1235, -0.3376,  ..., -0.0098, -0.0411, -0.1000],
#           [ 0.0887, -0.3926, -0.2427,  ..., -0.2517,  0.1204,  0.0648],
#           [-0.1672, -0.0927,  0.0096,  ..., -0.0714,  0.2647,  0.0790],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.5139,  0.5984,  0.4705,  ..., -0.5322,  0.0699,  0.0897],
#           [-0.1822,  0.5166,  0.3961,  ..., -0.2871,  0.6950, -0.0857],
#           [-0.1240,  0.7549,  0.5064,  ..., -0.2394,  0.7284, -0.1667],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3145,  0.9352,  0.0458,  ..., -0.3274, -0.5096, -0.3959],
#           [ 0.1040,  0.3492, -0.2020,  ..., -0.3711,  0.0091, -0.6589],
#           [-0.1056,  0.1341,  0.1969,  ..., -0.8175, -0.1212, -0.8515],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0684, -0.2887, -0.2804,  ..., -0.0453,  0.0474,  0.7436],
#           [ 0.4236, -0.2932, -0.1440,  ...,  0.4883,  0.1405,  0.2883],
#           [ 0.2748, -0.1596, -0.3074,  ...,  0.0704,  0.0358,  0.3250],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0442,  0.7630,  0.6090,  ...,  0.2349,  0.0395, -0.3569],
#           [-0.2345,  0.4063,  0.4660,  ...,  0.4950, -0.0966, -0.3017],
#           [-0.3907,  0.2365,  0.5229,  ...,  0.7762,  0.2454, -0.2196],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.0111,  0.0752, -0.1729,  ..., -0.3037, -0.5318, -0.1212],
#           [-0.7403,  0.2752, -0.1268,  ..., -0.0615, -0.1890, -0.4265],
#           [-0.2375,  0.0325, -0.0336,  ..., -0.3959, -0.1566, -0.3972],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2788, -0.1235, -0.3376,  ..., -0.0098, -0.0411, -0.1000],
#           [ 0.0887, -0.3926, -0.2427,  ..., -0.2517,  0.1204,  0.0648],
#           [-0.1672, -0.0927,  0.0096,  ..., -0.0714,  0.2647,  0.0790],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.5139,  0.5984,  0.4705,  ..., -0.5322,  0.0699,  0.0897],
#           [-0.1822,  0.5166,  0.3961,  ..., -0.2871,  0.6950, -0.0857],
#           [-0.1240,  0.7549,  0.5064,  ..., -0.2394,  0.7284, -0.1667],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3145,  0.9352,  0.0458,  ..., -0.3274, -0.5096, -0.3959],
#           [ 0.1040,  0.3492, -0.2020,  ..., -0.3711,  0.0091, -0.6589],
#           [-0.1056,  0.1341,  0.1969,  ..., -0.8175, -0.1212, -0.8515],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0684, -0.2887, -0.2804,  ..., -0.0453,  0.0474,  0.7436],
#           [ 0.4236, -0.2932, -0.1440,  ...,  0.4883,  0.1405,  0.2883],
#           [ 0.2748, -0.1596, -0.3074,  ...,  0.0704,  0.0358,  0.3250],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0442,  0.7630,  0.6090,  ...,  0.2349,  0.0395, -0.3569],
#           [-0.2345,  0.4063,  0.4660,  ...,  0.4950, -0.0966, -0.3017],
#           [-0.3907,  0.2365,  0.5229,  ...,  0.7762,  0.2454, -0.2196],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.0111,  0.0752, -0.1729,  ..., -0.3037, -0.5318, -0.1212],
#           [-0.7403,  0.2752, -0.1268,  ..., -0.0615, -0.1890, -0.4265],
#           [-0.2375,  0.0325, -0.0336,  ..., -0.3959, -0.1566, -0.3972],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.2788, -0.1235, -0.3376,  ..., -0.0098, -0.0411, -0.1000],
#           [ 0.0887, -0.3926, -0.2427,  ..., -0.2517,  0.1204,  0.0648],
#           [-0.1672, -0.0927,  0.0096,  ..., -0.0714,  0.2647,  0.0790],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.5139,  0.5984,  0.4705,  ..., -0.5322,  0.0699,  0.0897],
#           [-0.1822,  0.5166,  0.3961,  ..., -0.2871,  0.6950, -0.0857],
#           [-0.1240,  0.7549,  0.5064,  ..., -0.2394,  0.7284, -0.1667],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.3145,  0.9352,  0.0458,  ..., -0.3274, -0.5096, -0.3959],
#           [ 0.1040,  0.3492, -0.2020,  ..., -0.3711,  0.0091, -0.6589],
#           [-0.1056,  0.1341,  0.1969,  ..., -0.8175, -0.1212, -0.8515],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[-0.0684, -0.2887, -0.2804,  ..., -0.0453,  0.0474,  0.7436],
#           [ 0.4236, -0.2932, -0.1440,  ...,  0.4883,  0.1405,  0.2883],
#           [ 0.2748, -0.1596, -0.3074,  ...,  0.0704,  0.0358,  0.3250],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0442,  0.7630,  0.6090,  ...,  0.2349,  0.0395, -0.3569],
#           [-0.2345,  0.4063,  0.4660,  ...,  0.4950, -0.0966, -0.3017],
#           [-0.3907,  0.2365,  0.5229,  ...,  0.7762,  0.2454, -0.2196],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]],
#        grad_fn=<CatBackward0>))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # model.batch_generate(['x : ℝ\n⊢ log |x| = log x', 'n : ℕ∞,\nh : n ≤ 0\n⊢ ↑0 - ↑n ≤ ↑(0 - n)'], None, 2)
# ----> 2 model.batch_generate(['abc', 'abcde'], None, 3)
#
# File ~/Documents/phd/bait/models/end_to_end/tactic_models/gen_tac_model.py:159, in GenTacModel.batch_generate(self, state, retriever_args, num_samples)
#     157     return self.sample_gen(state, state_ids, state_mask, num_samples)
#     158 elif self.gen_config.strategy == 'beam':
# --> 159     return self.beamsearch_gen(state, state_ids, state_mask, num_samples)
#
# File ~/Documents/phd/bait/models/end_to_end/tactic_models/ilql/ilql_model.py:899, in PerTokenIQL.beamsearch_gen(self, state, state_ids, state_mask, num_samples, temp, top_k, top_p, exp_adv, adv_weight, adv_clip, include_logits, include_adv)
#     891 fixed_kvs = map_all_kvs(lambda x: x[(batch_indicator * num_samples + torch.div(top_k_, vocab_size,
#     892                                                                                rounding_mode='trunc')).reshape(
#     893     -1), :, :, :], model_outputs['qv_model_outputs'].past_key_values)
#     895 kvs['qv'] = map_all_kvs(lambda x: x[(batch_indicator * num_samples + torch.div(top_k_, vocab_size,
#     896                                                                                rounding_mode='trunc')).reshape(
#     897     -1), :, :, :], kvs['qv'])
# --> 899 kvs['qv'] = update_kvs(kvs['qv'], fixed_kvs, torch.arange(0, n).to(device), t - 1)
#     901 if 'target' in kvs:
#     902     fixed_target_kvs = map_all_kvs(
#     903         lambda x: x[(batch_indicator * num_samples + torch.div(top_k_, vocab_size,
#     904                                                                rounding_mode='trunc')).reshape(
#     905             -1), :, :, :], model_outputs['target_model_outputs'].past_key_values)
#
# File ~/Documents/phd/bait/models/end_to_end/tactic_models/ilql/ilql_model.py:27, in update_kvs(kvs, updated_kvs, lens_chosen, idx)
#      25 for i, layer in enumerate(kvs):
#      26     for x, item in enumerate(layer):
# ---> 27         item[lens_chosen, :, idx, :] = updated_kvs[i][x][:, :, idx, :]
#      28 return kvs
#
# IndexError: index 3 is out of bounds for dimension 2 with size 1
