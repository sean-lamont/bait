# %%
from models.end_to_end.search_models.goal_models.pair_model.datamodule import PairGoalDataModule


module = PairGoalDataModule(model_name='sean-lamont/leandojo-lean3-reprover-novel-premises', replace='drop', batch_size=1, num_workers=0, eval_batch_size=1, max_seq_len=2300, critic_tok='<extra_id_0>', provable_tok='<extra_id_1>', unprovable_tok='<extra_id_2>', trace_files='../runs/bestfs-novel-2/')
# Out:
# [2024-05-31 18:37:06,603] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.0), only 1.0.0 is known to be compatible
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
module.prepare_data()
# Out:
# 2024-05-31 18:36:32.997 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:74 - testst
# 2024-05-31 18:36:33.003 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:82 - Collection exists, dropping.
# 2024-05-31 18:36:33.005 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:87 - Loading traces..
# 2024-05-31 18:36:33.019 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:170 - Processing traces for training goal model...
#   0%|          | 2/1800 [00:00<02:16, 13.19it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 module.prepare_data()
#
# File ~/bait/models/end_to_end/search_models/goal_models/pair_model/datamodule.py:178, in PairGoalDataModule.prepare_data(self)
#     175     if isinstance(trace.tree, ErrorNode) or not trace.tree.out_edges:
#     176         continue
# --> 178     add_trace(trace, 'train')
#     180 logger.info('Processing traces for validating goal model...')
#     182 for file in tqdm(trace_files[int(0.9 * len(trace_files)):]):
#
# File ~/bait/models/end_to_end/search_models/goal_models/pair_model/datamodule.py:148, in PairGoalDataModule.prepare_data.<locals>.add_trace(trace, split)
#     143     negative = get_most_visited_sibling(parent, node,
#     144                                         lambda x: x.status != Status.PROVED)
#     146     if negative:
#     147         node_data = {'positive_goal': node.data['augmented_state'],
# --> 148                      'negative_goal': negative.data['augmented_state'], 'split': split,
#     149                      'n_visits': visits[negative.goal],
#     150                      'p_visits': visits[node.goal],
#     151                      'type': 'proven_pair'}
#     153         collection.insert_one(node_data)
#     155 for node in failed:
#     156     # just take one parent for now
#
# AttributeError: 'InternalNode' object has no attribute 'data'

# %%
module.batch_size
# Out:
#   Cell In[5], line 1
#     module.
#            ^
# SyntaxError: invalid syntax
