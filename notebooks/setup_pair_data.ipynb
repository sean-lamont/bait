# %%
from models.end_to_end.search_models.goal_models.pair_model.datamodule import PairGoalDataModule


module = PairGoalDataModule(model_name='sean-lamont/leandojo-lean3-reprover-novel-premises', replace='drop', batch_size=1, num_workers=0, eval_batch_size=1, max_seq_len=2300, critic_tok='<extra_id_0>', provable_tok='<extra_id_1>', unprovable_tok='<extra_id_2>', trace_files='../runs/bestfs-novel-2/')
# Out:
# [2024-06-03 14:23:05,832] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.0), only 1.0.0 is known to be compatible
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
module.prepare_data()
# Out:
# 2024-06-03 14:23:09.377 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:82 - Collection exists, dropping.
# 2024-06-03 14:23:09.377 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:87 - Loading traces..
# 2024-06-03 14:23:09.389 | INFO     | models.end_to_end.search_models.goal_models.pair_model.datamodule:prepare_data:238 - Processing traces for training goal model...
#   0%|          | 1/1800 [00:00<01:32, 19.45it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 module.prepare_data()
#
# File ~/bait/models/end_to_end/search_models/goal_models/pair_model/datamodule.py:246, in PairGoalDataModule.prepare_data(self)
#     243     if isinstance(trace.tree, ErrorNode) or not trace.tree.out_edges:
#     244         continue
# --> 246     add_trace(trace, 'train')
#     248 logger.info('Processing traces for validating goal model...')
#     250 for file in tqdm(trace_files[int(0.9 * len(trace_files)):]):
#
# File ~/bait/models/end_to_end/search_models/goal_models/pair_model/datamodule.py:215, in PairGoalDataModule.prepare_data.<locals>.add_trace(trace, split)
#     212 if not trace.proof:
#     213     for node in nodes:
#     214         # todo magic number
# --> 215         if visits[node.goal] > 256 and isinstance(node,
#     216                                                   InternalNode) and node.status != Status.PROVED and node.in_edges:
#     218             parent = node.in_edges[0].src
#     219             positive = get_least_visited_sibling(parent, node,
#     220                                                  lambda
#     221                                                      x: x.status != Status.FAILED)  # and x.visit_count > 0)
#
# AttributeError: 'str' object has no attribute 'goal'

# %%
module.batch_size
