# %%
import json
data = json.load(open('../data/LeanDojo/data/leandojo_benchmark/novel_premises/train.json'))
data.extend(json.load(open('../data/LeanDojo/data/leandojo_benchmark/novel_premises/val.json')))
data.extend(json.load(open('../data/LeanDojo/data/leandojo_benchmark/novel_premises/test.json')))

# %%
[a for a in data if a['full_name'] == 'tree.num_leaves_eq_num_nodes_succ']

# %%
data = json.load(open('deepseek_data.jsonl'))

# %%
lines = []
with open('deepseek_data.jsonl', 'w') as f:
    for d in f:
        lines.append(d)

# %%
len(lines)

# %%
lines[0]
